# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
cv2.__version__
# Out:
# '4.9.0'

# %%
#初始化
detector = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml") # 載入人臉追蹤模型
recog = cv2.face.LBPHFaceRecognizer_create()      # 啟用訓練人臉模型方法
faces = []   # 儲存人臉位置大小的串列
ids = []     # 記錄該人臉 id 的串列

# %%
import os 
imagelist=os.listdir('./outputTest/')
for i in imagelist:
    file_name = "./outputTest/"+i
    print(file_name)
    img = cv2.imread(file_name)       # 依序開啟每一張Tony_Blair的照片
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    face = detector.detectMultiScale(gray,1.2)# 擷取人臉區域
    for(x,y,w,h) in face:
        cv2.rectangle(gray,(x,y),(x+w,y+h),(0,255,0),2)
        cv2.namedWindow('My Image',0)
        cv2.resizeWindow('My Image',1000,1000)
        cv2.imshow('My Image', gray)
        cv2.waitKey(0)
        cv2.destroyAllWindows()
# Out:
# ./outputTest/(30).jpg
# ./outputTest/(31).jpg
# ./outputTest/(32).jpg
# ./outputTest/(33).jpg
# ./outputTest/(34).jpg
# ./outputTest/(35).jpg
# ./outputTest/(36).jpg
# ./outputTest/(37).jpg
# ./outputTest/(38).jpg
# ./outputTest/(39).jpg
# ./outputTest/(40).jpg
# ./outputTest/(41).jpg
# ./outputTest/(42).jpg
# ./outputTest/(43).jpg
# ./outputTest/(44).jpg
# ./outputTest/(45).jpg
# ./outputTest/0 (1).jpg
# ./outputTest/0 (12).jpg
# ./outputTest/0 (13).jpg
# ./outputTest/0 (14).jpg
# ./outputTest/0 (15).jpg
# ./outputTest/0 (17).jpg
# ./outputTest/0 (18).jpg
# ./outputTest/0 (19).jpg
# ./outputTest/0 (20).jpg
# ./outputTest/0 (22).jpg
# ./outputTest/0 (24).jpg
# ./outputTest/0 (25).jpg
# ./outputTest/0 (27).jpg
# ./outputTest/0 (29).jpg
# ./outputTest/0 (30).jpg
# ./outputTest/0 (31).jpg
# ./outputTest/0 (32).jpg
# ./outputTest/0 (33).jpg
# ./outputTest/0 (34).jpg
# ./outputTest/0 (45).jpg
# ./outputTest/0 (46).jpg
# ./outputTest/0 (47).jpg
# ./outputTest/20240225_183907_2_0.jpg
# ./outputTest/20240225_183909_0_0.jpg
# ./outputTest/20240225_183911_1_0.jpg
# ./outputTest/20240225_183915_3_0.jpg

# %%
#讀取HAOVideoOutput圖片

import os 
imagelist=os.listdir('./haoOutput/')
for i in imagelist:
    print(i)
    
for i in imagelist:
    face=()
    file_name = "./haoOutput/"+i
    print(file_name)
    img = cv2.imread(file_name)       # 依序開啟每一張Tony_Blair的照片
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img_np = np.array(gray,'uint8')           # 轉換成指定編碼的 numpy 陣列
#     print(img_np)
    face = detector.detectMultiScale(gray,1.2)# 擷取人臉區域
    print(len(face))
    if(len(face)==1):
        for(x,y,w,h) in face:
            faces.append(img_np[y:y+h,x:x+w])         # 記錄蔡英文人臉的位置和大小內像素的數值
            ids.append(2)                            # 記錄蔡英文人臉對應的 id，只能是整數，都是 1 表示蔡英文的 id 為 1
print("訓練張數:",len(faces))
print("標記id:",len(ids))
# Out:
# haoOutput00000000.jpg
# haoOutput00000001.jpg
# haoOutput00000002.jpg
# haoOutput00000003.jpg
# haoOutput00000004.jpg
# haoOutput00000005.jpg
# haoOutput00000006.jpg
# haoOutput00000007.jpg
# haoOutput00000008.jpg
# haoOutput00000009.jpg
# haoOutput00000010.jpg
# haoOutput00000011.jpg
# haoOutput00000012.jpg
# haoOutput00000013.jpg
# haoOutput00000014.jpg
# haoOutput00000015.jpg
# haoOutput00000016.jpg
# haoOutput00000017.jpg
# haoOutput00000018.jpg
# haoOutput00000019.jpg
# ./haoOutput/haoOutput00000212.jpg
# 1
# ./haoOutput/haoOutput00000213.jpg
# 2
# ./haoOutput/haoOutput00000214.jpg
# 1
# ./haoOutput/haoOutput00000215.jpg
# 1
# ./haoOutput/haoOutput00000216.jpg
# 1
# ./haoOutput/haoOutput00000217.jpg
# 2
# ./haoOutput/haoOutput00000218.jpg
# 2
# ./haoOutput/haoOutput00000219.jpg
# 1
# ./haoOutput/haoOutput00000220.jpg
# 1
# ./haoOutput/haoOutput00000221.jpg
# 1
# ./haoOutput/haoOutput00000222.jpg
# 1
# ./haoOutput/haoOutput00000223.jpg
# 1
# ./haoOutput/haoOutput00000224.jpg
# 1
# ./haoOutput/haoOutput00000225.jpg
# 1
# ./haoOutput/haoOutput00000226.jpg
# 2
# ./haoOutput/haoOutput00000227.jpg
# 2
# ./haoOutput/haoOutput00000228.jpg
# 3
# ./haoOutput/haoOutput00000229.jpg
# 1
# ./haoOutput/haoOutput00000230.jpg
# 1
# ./haoOutput/haoOutput00000231.jpg
# 1
# ./haoOutput/haoOutput00000232.jpg
# 1
# ./haoOutput/haoOutput00000233.jpg
# 1
# ./haoOutput/haoOutput00000234.jpg
# 1
# ./haoOutput/haoOutput00000235.jpg
# 1
# ./haoOutput/haoOutput00000236.jpg
# 1
# ./haoOutput/haoOutput00000237.jpg
# 2
# ./haoOutput/haoOutput00000238.jpg
# 3
# ./haoOutput/haoOutput00000239.jpg
# 2
# ./haoOutput/haoOutput00000240.jpg
# 1
# ./haoOutput/haoOutput00000241.jpg
# 1
# ./haoOutput/haoOutput00000242.jpg
# 1
# ./haoOutput/haoOutput00000243.jpg
# 2
# ./haoOutput/haoOutput00000244.jpg
# 1
# ./haoOutput/haoOutput00000245.jpg
# 1
# ./haoOutput/haoOutput00000246.jpg
# 2
# ./haoOutput/haoOutput00000247.jpg
# 1
# ./haoOutput/haoOutput00000248.jpg
# 1
# ./haoOutput/haoOutput00000249.jpg
# 1
# ./haoOutput/haoOutput00000250.jpg
# 1
# ./haoOutput/haoOutput00000251.jpg
# 1
# ./haoOutput/haoOutput00000252.jpg
# 1
# ./haoOutput/haoOutput00000253.jpg
# 1
# ./haoOutput/haoOutput00000254.jpg
# 1
# ./haoOutput/haoOutput00000255.jpg
# 1
# ./haoOutput/haoOutput00000256.jpg
# 1
# ./haoOutput/haoOutput00000257.jpg
# 2
# ./haoOutput/haoOutput00000258.jpg
# 1
# ./haoOutput/haoOutput00000259.jpg
# 1
# ./haoOutput/haoOutput00000260.jpg
# 1
# ./haoOutput/haoOutput00000261.jpg
# 1
# ./haoOutput/haoOutput00000262.jpg
# 1
# ./haoOutput/haoOutput00000263.jpg

# %%
#讀取KennyVideoOutput圖片

import os 
imagelist=os.listdir('./kenny2Output/')
for i in imagelist:
    print(i)
    
for i in imagelist:
    face=()
    file_name = "./kenny2Output/"+i
    print(file_name)
    img = cv2.imread(file_name)       # 依序開啟每一張Tony_Blair的照片
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img_np = np.array(gray,'uint8')           # 轉換成指定編碼的 numpy 陣列
#     print(img_np)
    face = detector.detectMultiScale(gray,1.2)# 擷取人臉區域
    print(len(face))
        
    if(len(face)==1):
        for(x,y,w,h) in face:
            faces.append(img_np[y:y+h,x:x+w])         # 記錄蔡英文人臉的位置和大小內像素的數值
            ids.append(1)                        # 記錄蔡英文人臉對應的 id，只能是整數，都是 1 表示蔡英文的 id 為 1
            cv2.rectangle(img_np,(x,y),(x+w,y+h),(0,255,0),2)
            cv2.namedWindow('My Image',0)
            cv2.resizeWindow('My Image',1000,1000)
            cv2.imshow('My Image', img_np)
            cv2.waitKey(0)
            cv2.destroyAllWindows()

cv2.waitKey(0)
cv2.destroyAllWindows()
    
    
print("訓練張數:",len(faces))
print("標記id:",len(ids))
# Out:
# 20240225_182800_6_0.jpg
# 20240225_182807_4_0.jpg
# 20240225_182810_3_0.jpg
# 20240225_182812_2_0.jpg
# 20240225_182815_5_0.jpg
# 20240225_182817_7_0.jpg
# 20240225_182821_1_0.jpg
# 20240225_182831_0_0.jpg
# ./kenny2Output/20240225_182800_6_0.jpg
# 1
# ./kenny2Output/20240225_182807_4_0.jpg
# 0
# ./kenny2Output/20240225_182810_3_0.jpg
# 1
# ./kenny2Output/20240225_182812_2_0.jpg
# 1
# ./kenny2Output/20240225_182815_5_0.jpg
# 1
# ./kenny2Output/20240225_182817_7_0.jpg
# 0
# ./kenny2Output/20240225_182821_1_0.jpg
# 0
# ./kenny2Output/20240225_182831_0_0.jpg
# 0
# 訓練張數: 4
# 標記id: 4

# %%
#讀取TisaVideoOutput圖片

import os 
imagelist=os.listdir('./picture/tisa/')
for i in imagelist:
    print(i)
    
for i in imagelist:
    face=()
    file_name = "./picture/tisa/"+i
    print(file_name)
    img = cv2.imread(file_name)       # 依序開啟每一張Tony_Blair的照片
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img_np = np.array(gray,'uint8')           # 轉換成指定編碼的 numpy 陣列
#     print(img_np)
    face = detector.detectMultiScale(gray,1.2)# 擷取人臉區域
    print(len(face))
        
    if(len(face)==1):
        for(x,y,w,h) in face:
            faces.append(img_np[y:y+h,x:x+w])         # 記錄蔡英文人臉的位置和大小內像素的數值
            ids.append(2)                        # 記錄蔡英文人臉對應的 id，只能是整數，都是 1 表示蔡英文的 id 為 1
            cv2.rectangle(img_np,(x,y),(x+w,y+h),(0,255,0),2)
            cv2.namedWindow('My Image',0)
            cv2.resizeWindow('My Image',1000,1000)
            cv2.imshow('My Image', img_np)
            cv2.waitKey(0)
            cv2.destroyAllWindows()

cv2.waitKey(0)
cv2.destroyAllWindows()
    
    
print("訓練張數:",len(faces))
print("標記id:",len(ids))
# Out:
# (1).jpg
# (1).png
# (10).jpg
# (11).jpg
# (12).jpg
# (13).jpg
# (14).jpg
# (15).jpg
# (16).jpg
# (17).jpg
# (18).jpg
# (19).jpg
# (2).jpg
# (20).jpg
# (21).jpg
# (22).jpg
# (23).jpg
# (24).jpg
# (25).jpg
# (26).jpg
# (27).jpg
# (28).jpg
# (29).jpg
# (3).jpg
# (30).jpg
# (4).jpg
# (5).jpg
# (6).jpg
# (7).jpg
# (8).jpg
# (9).jpg
# ./picture/tisa/(1).jpg
# 1
# ./picture/tisa/(1).png
# 1
# ./picture/tisa/(10).jpg
# 1
# ./picture/tisa/(11).jpg
# 1
# ./picture/tisa/(12).jpg
# 1
# ./picture/tisa/(13).jpg
# 1
# ./picture/tisa/(14).jpg
# 1
# ./picture/tisa/(15).jpg
# 1
# ./picture/tisa/(16).jpg
# 1
# ./picture/tisa/(17).jpg
# 1
# ./picture/tisa/(18).jpg
# 1
# ./picture/tisa/(19).jpg
# 1
# ./picture/tisa/(2).jpg
# 2
# ./picture/tisa/(20).jpg
# 3
# ./picture/tisa/(21).jpg
# 1
# ./picture/tisa/(22).jpg
# 1
# ./picture/tisa/(23).jpg
# 1
# ./picture/tisa/(24).jpg
# 1
# ./picture/tisa/(25).jpg
# 1
# ./picture/tisa/(26).jpg
# 2
# ./picture/tisa/(27).jpg
# 1
# ./picture/tisa/(28).jpg
# 3
# ./picture/tisa/(29).jpg
# 1
# ./picture/tisa/(3).jpg
# 1
# ./picture/tisa/(30).jpg
# 1
# ./picture/tisa/(4).jpg
# 1
# ./picture/tisa/(5).jpg
# 1
# ./picture/tisa/(6).jpg
# 2
# ./picture/tisa/(7).jpg
# 3
# ./picture/tisa/(8).jpg
# 1
# ./picture/tisa/(9).jpg
# 1
# 訓練張數: 29
# 標記id: 29

# %%
print(len(faces))
print(ids)
# Out:
# 29
# [1, 1, 1, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]

# %%
print('training...')                              # 提示開始訓練
recog.train(faces,np.array(ids))                  # 開始訓練
recog.save('face.yml')                            # 訓練完成儲存為 face.yml
print('ok!')
# Out:
# training...
# ok!

# %%
#開始辨識 利用 face.yml

# %%
  name = {
        '1':'kennychuang',
        '2':'Tsai',
        '3':'oxxostudio'
    }

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
recognizer = cv2.face.LBPHFaceRecognizer_create()         # 啟用訓練人臉模型方法
recognizer.read('face.yml')                               # 讀取人臉模型檔
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml') # 載入人臉追蹤模型

# %%
img = cv2.imread('./outputTest/(5).jpg')
# img = cv2.imread('./picture/Tony_Blair/Tony_Blair_00.jpg')
# img = cv2.resize(img,(1620,900))              # 縮小尺寸，加快辨識效率
gray = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)  # 轉換成黑白
faces = face_cascade.detectMultiScale(gray,1.2)  # 追蹤人臉 ( 目的在於標記出外框 )
print(faces)
# plt.imshow(gray) 
for(x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)            # 標記人臉外框
        idnum,confidence = recognizer.predict(gray[y:y+h,x:x+w]) # 取出 id 號碼以及信心指數 confidence
        print(confidence)
        if confidence < 60:
            text = name[str(idnum)]                             # 如果信心指數小於 60，取得對應的名字
        else:
            text = '???'
        print(text)
        cv2.putText(img, text, (x,y-5),cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255,0), 2, cv2.LINE_AA)
# plt.imshow(img)
cv2.namedWindow('My Image',0)
cv2.resizeWindow('My Image',1000,1000)
cv2.imshow('My Image', img)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [[287 766 367 367]]
# 27.525364623182917
# kennychuang

# %%
import os 
imagelist=os.listdir('./outputTest/')
dataNumber=0
correctnumber=0
face1Number=0
for i in imagelist:
    print(i)
    dataNumber+=1
print(dataNumber)
print("---------------------------------------------------------------")
for i in imagelist:
    face=()
    faces=()
    file_name = "./outputTest/"+i
    img = cv2.imread(file_name)
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)  # 轉換成黑白
    faces = face_cascade.detectMultiScale(gray,1.2)  # 追蹤人臉 ( 目的在於標記出外框 )
    if(len(faces)==1):
            face1Number+=1
#     print(i)
#     print(len(faces))
    for(x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)            # 標記人臉外框
        idnum,confidence = recognizer.predict(gray[y:y+h,x:x+w]) # 取出 id 號碼以及信心指數 confidence
#         print(confidence)
        
        if confidence < 60:
            text = name[str(idnum)]                               # 如果信心指數小於 60，取得對應的名字
            print(i)
            print(idnum)
            print(confidence)
            correctnumber+=1
        else:
            text = '???'
        cv2.putText(img, text, (x,y-5),cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255,0), 2, cv2.LINE_AA)
        cv2.imwrite('./result/'+i, img)  
print(correctnumber)
print('------------------------------------------')
print('face1Number=',face1Number)
# Out:
# (30).jpg
# (31).jpg
# (32).jpg
# (33).jpg
# (34).jpg
# (35).jpg
# (36).jpg
# (37).jpg
# (38).jpg
# (39).jpg
# (40).jpg
# (41).jpg
# (42).jpg
# (43).jpg
# (44).jpg
# (45).jpg
# 0 (1).jpg
# 0 (12).jpg
# 0 (13).jpg
# 0 (14).jpg
# 0 (15).jpg
# 0 (17).jpg
# 0 (18).jpg
# 0 (19).jpg
# 0 (20).jpg
# 0 (22).jpg
# 0 (24).jpg
# 0 (25).jpg
# 0 (27).jpg
# 0 (29).jpg
# 0 (30).jpg
# 0 (31).jpg
# 0 (32).jpg
# 0 (33).jpg
# 0 (34).jpg
# 0 (38).jpg
# 0 (39).jpg
# 0 (40).jpg
# 0 (41).jpg
# 0 (42).jpg
# 0 (43).jpg
# 0 (44).jpg
# 0 (45).jpg
# 0 (46).jpg
# 0 (47).jpg
# 20240225_183907_2_0.jpg
# 20240225_183909_0_0.jpg
# 20240225_183911_1_0.jpg
# 20240225_183915_3_0.jpg
# 20240225_212805_4_0.jpg
# 20240225_212843_3_0.jpg
# 20240225_212850_2_0.jpg
# 20240225_212858_1_0.jpg
# 20240225_212935_0_0.jpg
# 20240225_212942_5_0.jpg
# 55
# ---------------------------------------------------------------
# (32).jpg
# 2
# 44.513183261664935
# (33).jpg
# 2
# 48.92850546686939
# (34).jpg
# 2
# 57.44587408640318
# (36).jpg
# 2
# 41.8117452987971
# (37).jpg
# 2
# 54.29143038571852
# (39).jpg
# 2
# 36.75914426999995
# (40).jpg
# 2
# 32.46184970342533
# 0 (13).jpg
# 2
# 48.82129919291422
# 0 (14).jpg
# 1
# 40.512185349438695
# 0 (14).jpg
# 2
# 39.852998687119076
# 0 (15).jpg
# 2
# 57.85727804904769
# 0 (17).jpg
# 2
# 56.55860401937635
# 0 (18).jpg
# 2
# 55.36817580839088
# 0 (19).jpg
# 2
# 54.05034772622631
# 0 (20).jpg
# 2
# 37.72471037173184
# 0 (20).jpg
# 2
# 43.93381487366386
# 0 (22).jpg
# 2
# 56.46304706864495
# 0 (25).jpg
# 2
# 56.39749036378985
# 0 (29).jpg
# 1
# 34.046260851057035
# 0 (30).jpg
# 1
# 34.69900983812611
# 0 (31).jpg
# 1
# 25.904880451997926
# 0 (32).jpg
# 1
# 30.485161716586042
# 0 (34).jpg
# 1
# 24.272335862630836
# 0 (41).jpg
# 2
# 58.07530931813726
# 0 (44).jpg
# 2
# 52.153741546958905
# 0 (45).jpg
# 1
# 43.43352266521147
# 0 (46).jpg
# 1
# 51.394423377954595
# 20240225_183907_2_0.jpg
# 1
# 18.353097562094906
# 20240225_183911_1_0.jpg
# 1
# 15.979940234441436
# 20240225_212805_4_0.jpg
# 1
# 20.92291159856889
# 20240225_212805_4_0.jpg
# 1
# 58.66302623800886
# 20240225_212843_3_0.jpg
# 1
# 38.306622929029736
# 20240225_212850_2_0.jpg
# 1
# 42.710754690462004
# 20240225_212858_1_0.jpg
# 1
# 44.15420076439723
# 20240225_212935_0_0.jpg
# 1
# 36.86810827851232
# 20240225_212942_5_0.jpg
# 1
# 33.07696980214002
# 36
# ------------------------------------------
# face1Number= 34
